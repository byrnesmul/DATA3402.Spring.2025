# %% [markdown]
# ## Lab 2- Tic Tac Toe
#
# In this lab your will build a n x n Tic Tac Toe game. As you do the exercises, make sure your solutions work for any size Tic Tac Toe game.

# %% [markdown]
# *Exercise 1:* Write a function that creates an n by n matrix (of list of lists) which will represent the state of a Tie Tac Toe game. Let 0, 1, and 2 represent empty, "X", and "O", respectively.

# %%
# Write you solution here

def create_board(n):
    return [[0 for _ in range(n)] for _ in range(n)]

# %%
# Test your solution here

print(create_board(3))
# Out:
# [[0, 0, 0], [0, 0, 0], [0, 0, 0]]

# %% [markdown]
# *Exercise 2:* Write a function that takes 2 integers `n` and `m` as input and draws a `n` by `m` game board. For example the following is a 3x3 board:
# ```
#    --- --- ---
#   |   |   |   |
#    --- --- ---
#   |   |   |   |
#    --- --- ---
#   |   |   |   |
#    --- --- ---
#    ```

# %%
# Write you solution here

def draw_board(n, m):
    for i in range(n):
        print(" ---" * m)
        print("|   " * (m + 1))
    print(" ---" * m)

# %%
# Test your solution here
draw_board(3, 3)
# Out:
#  --- --- ---
# |   |   |   |
#  --- --- ---
# |   |   |   |
#  --- --- ---
# |   |   |   |
#  --- --- ---

# %% [markdown]
# *Exercise 3:* Modify exercise 2, so that it takes a matrix of the form from exercise 1 and draws a tic-tac-tie board with "X"s and "O"s.

# %%
# Write you solution here

def draw_board_with_pieces(board):
    n = len(board)
    for i in range(n):
        print(" ---" * n)
        row = "|"
        for j in range(n):
            cell = board[i][j]
            if cell == 0:
                row += "   |"
            elif cell == 1:
                row += " X |"
            else:
                row += " O |"
        print(row)
    print(" ---" * n)

# %%
# Test your solution here
draw_board_with_pieces([[1, 0, 2], [0, 1, 0], [2, 0, 1]])
# Out:
#  --- --- ---
# | X |   | O |
#  --- --- ---
# |   | X |   |
#  --- --- ---
# | O |   | X |
#  --- --- ---

# %% [markdown]
# *Exercise 4:* Write a function that takes a `n` by `n` matrix representing a tic-tac-toe game, and returns -1, 0, 1, or 2 indicating the game is incomplete, the game is a draw, player 1 has won, or player 2 has one, respectively. Here are some example inputs you can use to test your code:

# %%
# Write you solution here
def check_winner(board):
    n = len(board)

    # Check rows and columns
    for i in range(n):
        if board[i].count(board[i][0]) == n and board[i][0] != 0:
            return board[i][0]
        if all(board[j][i] == board[0][i] for j in range(n)) and board[0][i] != 0:
            return board[0][i]

    # Check diagonals
    if all(board[i][i] == board[0][0] for i in range(n)) and board[0][0] != 0:
        return board[0][0]
    if all(board[i][n - 1 - i] == board[0][n - 1] for i in range(n)) and board[0][n - 1] != 0:
        return board[0][n - 1]

    return None

# %%
# Test your solution here
winner_is_2 = [[2, 2, 0],
	[2, 1, 0],
	[2, 1, 1]]
print(check_winner(winner_is_2))
# Out:
# 2

# %%
winner_is_2 = [[2, 2, 0],
	[2, 1, 0],
	[2, 1, 1]]

winner_is_1 = [[1, 2, 0],
	[2, 1, 0],
	[2, 1, 1]]

winner_is_also_1 = [[0, 1, 0],
	[2, 1, 0],
	[2, 1, 1]]

no_winner = [[1, 2, 0],
	[2, 1, 0],
	[2, 1, 2]]

also_no_winner = [[1, 2, 0],
	[2, 1, 0],
	[2, 1, 0]]

# %% [markdown]
# *Exercise 5:* Write a function that takes a game board, player number, and `(x,y)` coordinates and places "X" or "O" in the correct location of the game board. Make sure that you only allow filling previously empty locations. Return `True` or `False` to indicate successful placement of "X" or "O".

# %%
# Write you solution here

def place_move(board, player, x, y):
    if board[x][y] == 0:  
        board[x][y] = player  
        return True
    return False

# %%
# Test your solution here

board = create_board(3)
print(place_move(board, 1, 0, 0)) 
print(place_move(board, 2, 0, 0))  
print(board)
# Out:
# True
# False
# [[1, 0, 0], [0, 0, 0], [0, 0, 0]]

# %% [markdown]
# *Exercise 6:* Modify Exercise 3 to show column and row labels so that players can specify location using "A2" or "C1".

# %%
# Write you solution here
def draw_board_with_labels(board):
    n = len(board)
    labels = "   " + "   ".join([chr(65 + i) for i in range(n)])
    print(labels)
    for i in range(n):
        print(" ---" * n)
        row = f"{i+1}|"
        for j in range(n):
            cell = board[i][j]
            if cell == 0:
                row += "   |"
            elif cell == 1:
                row += " X |"
            else:
                row += " O |"
        print(row)
    print(" ---" * n)

# %%
# Test your solution here
draw_board_with_labels([[1, 0, 2], [0, 1, 0], [2, 0, 1]])
# Out:
#    A   B   C
#  --- --- ---
# 1| X |   | O |
#  --- --- ---
# 2|   | X |   |
#  --- --- ---
# 3| O |   | X |
#  --- --- ---

# %% [markdown]
# *Exercise 7:* Write a function that takes a board, player number, and location specified as in exercise 6 and then calls exercise 5 to correctly modify the board.

# %%
# Write you solution here
def place_piece_with_location(board, player, location):
    col = ord(location[0].upper()) - 65
    row = int(location[1]) - 1
    return place_move(board, player, row, col)

# %%
board = create_board(3)
print(place_piece_with_location(board, 1, 'A1'))  # Should return True
print(place_piece_with_location(board, 2, 'A1'))  # Should return False


draw_board_with_pieces(board)
# Out:
# True
# False
#  --- --- ---
# | X |   |   |
#  --- --- ---
# |   |   |   |
#  --- --- ---
# |   |   |   |
#  --- --- ---

# %% [markdown]
# *Exercise 8:* Write a function is called with a board and player number, takes input from the player using python's `input`, and modifies the board using your function from exercise 7. Note that you should keep asking for input until you have gotten a valid input that results in a valid move.

# %%
# Write you solution here
def get_player_move(board, player):
    n = len(board)
    while True:
        location = input(f"Player {player}, enter your move (e.g., A1): ").strip().upper()
        if len(location) == 2 and location[0] in [chr(65 + i) for i in range(n)] and location[1] in [str(i + 1) for i in range(n)]:
            if place_piece_with_location(board, player, location):
                break
            else:
                print("That spot is already taken. Try again.")
        else:
            print("Invalid input. Please enter a valid location (e.g., A1).")

# %%
# Test your solution here

board = create_board(3)

# Player 1 places a move
print("Player 1's turn (X):")
get_player_move(board, 1)  
draw_board_with_labels(board)

# Player 2 places a move
print("Player 2's turn (O):")
get_player_move(board, 2)  
draw_board_with_labels(board)

# Player 1 tries to place a move again
print("Player 1's turn (X):")
get_player_move(board, 1)  
draw_board_with_labels(board)
# Out:
# Player 1's turn (X):
# Player 1, enter your move (e.g., A1): A1
#    A   B   C
#  --- --- ---
# 1| X |   |   |
#  --- --- ---
# 2|   |   |   |
#  --- --- ---
# 3|   |   |   |
#  --- --- ---
# Player 2's turn (O):
# Player 2, enter your move (e.g., A1): B3
#    A   B   C
#  --- --- ---
# 1| X |   |   |
#  --- --- ---
# 2|   |   |   |
#  --- --- ---
# 3|   | O |   |
#  --- --- ---
# Player 1's turn (X):
# Player 1, enter your move (e.g., A1): C2
#    A   B   C
#  --- --- ---
# 1| X |   |   |
#  --- --- ---
# 2|   |   | X |
#  --- --- ---
# 3|   | O |   |
#  --- --- ---

# %% [markdown]
# *Exercise 9:* Use all of the previous exercises to implement a full tic-tac-toe game, where an appropriate board is drawn, 2 players are repeatedly asked for a location coordinates of where they wish to place a mark, and the game status is checked until a player wins or a draw occurs.

# %%
# Write you solution here
def create_board(n):
    return [[0 for _ in range(n)] for _ in range(n)]

def draw_board_with_labels(board):
    n = len(board)
    labels = "   " + "   ".join([chr(65 + i) for i in range(n)])
    print(labels)
    for i in range(n):
        print(" ---" * n)
        row = f"{i+1}|"
        for j in range(n):
            cell = board[i][j]
            if cell == 0:
                row += "   |"
            elif cell == 1:
                row += " X |"
            else:
                row += " O |"
        print(row)
    print(" ---" * n)

def check_winner(board):
    n = len(board)
    # Check rows and columns
    for i in range(n):
        if board[i].count(board[i][0]) == n and board[i][0] != 0:
            return board[i][0]
        if all(board[j][i] == board[0][i] for j in range(n)) and board[0][i] != 0:
            return board[0][i]
    # Check diagonals
    if all(board[i][i] == board[0][0] for i in range(n)) and board[0][0] != 0:
        return board[0][0]
    if all(board[i][n - 1 - i] == board[0][n - 1] for i in range(n)) and board[0][n - 1] != 0:
        return board[0][n - 1]
    # Check for draw
    if all(cell != 0 for row in board for cell in row):
        return 0
    return None

def place_piece(board, player, x, y):
    if board[x][y] == 0:
        board[x][y] = player
        return True
    return False

def place_piece_with_location(board, player, location):
    col = ord(location[0].upper()) - 65
    row = int(location[1]) - 1
    return place_piece(board, player, row, col)

def get_player_move(board, player):
    n = len(board)
    while True:
        location = input(f"Player {player}, enter your move (e.g., A1): ").strip().upper()
        if len(location) == 2 and location[0] in [chr(65 + i) for i in range(n)] and location[1] in [str(i + 1) for i in range(n)]:
            if place_piece_with_location(board, player, location):
                break
            else:
                print("That spot is already taken. Try again.")
        else:
            print("Invalid input. Please enter a valid location (e.g., A1).")

def play_tic_tac_toe(n):
    board = create_board(n)
    current_player = 1
    while True:
        draw_board_with_labels(board)
        get_player_move(board, current_player)
        winner = check_winner(board)
        if winner is not None:
            draw_board_with_labels(board)
            if winner == 1:
                print("Player 1 (X) wins!")
            elif winner == 2:
                print("Player 2 (O) wins!")
            else:
                print("It's a draw!")
            break
        current_player = 3 - current_player  # Switch players (1 -> 2, 2 -> 1)
# Out:
#    A   B   C
#  --- --- ---
# 1|   |   |   |
#  --- --- ---
# 2|   |   |   |
#  --- --- ---
# 3|   |   |   |
#  --- --- ---
# Player 1, enter your move (e.g., A1): A1
#    A   B   C
#  --- --- ---
# 1| X |   |   |
#  --- --- ---
# 2|   |   |   |
#  --- --- ---
# 3|   |   |   |
#  --- --- ---
# Player 2, enter your move (e.g., A1): A2
#    A   B   C
#  --- --- ---
# 1| X |   |   |
#  --- --- ---
# 2| O |   |   |
#  --- --- ---
# 3|   |   |   |
#  --- --- ---
# Player 1, enter your move (e.g., A1): B2
#    A   B   C
#  --- --- ---
# 1| X |   |   |
#  --- --- ---
# 2| O | X |   |
#  --- --- ---
# 3|   |   |   |
#  --- --- ---
# Player 2, enter your move (e.g., A1): A3
#    A   B   C
#  --- --- ---
# 1| X |   |   |
#  --- --- ---
# 2| O | X |   |
#  --- --- ---
# 3| O |   |   |
#  --- --- ---
# Player 1, enter your move (e.g., A1): C3
#    A   B   C
#  --- --- ---
# 1| X |   |   |
#  --- --- ---
# 2| O | X |   |
#  --- --- ---
# 3| O |   | X |
#  --- --- ---
# Player 1 (X) wins!

# %%
# Test your solution here
play_tic_tac_toe(3)
# Out:
#    A   B   C
#  --- --- ---
# 1|   |   |   |
#  --- --- ---
# 2|   |   |   |
#  --- --- ---
# 3|   |   |   |
#  --- --- ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Test your solution here
# ----> 2 play_tic_tac_toe(3)
#
# Cell In[23], line 69, in play_tic_tac_toe(n)
#      67 while True:
#      68     draw_board_with_labels(board)
# ---> 69     get_player_move(board, current_player)
#      70     winner = check_winner(board)
#      71     if winner is not None:
#
# Cell In[23], line 55, in get_player_move(board, player)
#      53 n = len(board)
#      54 while True:
# ---> 55     location = input(f"Player {player}, enter your move (e.g., A1): ").strip().upper()
#      56     if len(location) == 2 and location[0] in [chr(65 + i) for i in range(n)] and location[1] in [str(i + 1) for i in range(n)]:
# ...

# %% [markdown]
# *Exercise 10:* Test that your game works for 5x5 Tic Tac Toe.

# %%
play_tic_tac_toe(5)

# %% [markdown]
# *Exercise 11:* (Advanced / Challenge) Develop a version of the game where one player is the computer. Note that you don't need to do an extensive seach for the best move. You can have the computer simply protect against loosing and otherwise try to win with straight or diagonal patterns.

# %%
# Write you solution here

# %%
# Test your solution here
